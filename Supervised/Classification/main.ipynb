# %%
import pandas as pd

# %%
df = pd.read_csv("Phishing_Email.csv")

# %%
df
# Out:
#        Unnamed: 0                                         Email Text  \
# 0               0  re : 6 . 1100 , disc : uniformitarianism , re ...
# 1               1  the other side of * galicismos * * galicismo *...
# 2               2  re : equistar deal tickets are you still avail...
# 3               3  \nHello I am your hot lil horny toy.\n    I am...
# 4               4  software at incredibly low prices ( 86 % lower...
# ...           ...                                                ...
# 18645       18646  date a lonely housewife always wanted to date ...
# 18646       18647  request submitted : access request for anita ....
# 18647       18648  re : important - prc mtg hi dorn & john , as y...
# 18648       18649  press clippings - letter on californian utilit...
# 18649       18650                                              empty
#
#            Email Type
# 0          Safe Email
# 1          Safe Email
# 2          Safe Email
# 3      Phishing Email
# ...

# %%
if 'Unnamed: 0' in df.columns:
    df = df.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#                                               Email Text      Email Type
# 0      re : 6 . 1100 , disc : uniformitarianism , re ...      Safe Email
# 1      the other side of * galicismos * * galicismo *...      Safe Email
# 2      re : equistar deal tickets are you still avail...      Safe Email
# 3      \nHello I am your hot lil horny toy.\n    I am...  Phishing Email
# 4      software at incredibly low prices ( 86 % lower...  Phishing Email
# ...                                                  ...             ...
# 18645  date a lonely housewife always wanted to date ...  Phishing Email
# 18646  request submitted : access request for anita ....      Safe Email
# 18647  re : important - prc mtg hi dorn & john , as y...      Safe Email
# 18648  press clippings - letter on californian utilit...      Safe Email
# 18649                                              empty  Phishing Email
#
# [18650 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Email Text    16
# Email Type     0
# dtype: int64

# %%
df.dropna()
# Out:
#                                               Email Text      Email Type
# 0      re : 6 . 1100 , disc : uniformitarianism , re ...      Safe Email
# 1      the other side of * galicismos * * galicismo *...      Safe Email
# 2      re : equistar deal tickets are you still avail...      Safe Email
# 3      \nHello I am your hot lil horny toy.\n    I am...  Phishing Email
# 4      software at incredibly low prices ( 86 % lower...  Phishing Email
# ...                                                  ...             ...
# 18645  date a lonely housewife always wanted to date ...  Phishing Email
# 18646  request submitted : access request for anita ....      Safe Email
# 18647  re : important - prc mtg hi dorn & john , as y...      Safe Email
# 18648  press clippings - letter on californian utilit...      Safe Email
# 18649                                              empty  Phishing Email
#
# [18634 rows x 2 columns]

# %%
df['Email Type'] = df['Email Type'].map({'Safe Email': 0, 'Phishing Email': 1})

# %%
df = df[df['Email Text'].notnull() & (df['Email Text'].str.strip().str.lower() != 'empty')]
df
# Out:
#                                               Email Text  Email Type
# 0      re : 6 . 1100 , disc : uniformitarianism , re ...           0
# 1      the other side of * galicismos * * galicismo *...           0
# 2      re : equistar deal tickets are you still avail...           0
# 3      \nHello I am your hot lil horny toy.\n    I am...           1
# 4      software at incredibly low prices ( 86 % lower...           1
# ...                                                  ...         ...
# 18644  \nRick Moen  a Ã©crit:> > I'm confused. I thou...           0
# 18645  date a lonely housewife always wanted to date ...           1
# 18646  request submitted : access request for anita ....           0
# 18647  re : important - prc mtg hi dorn & john , as y...           0
# 18648  press clippings - letter on californian utilit...           0
#
# [18101 rows x 2 columns]

# %%
X = df['Email Text']
y = df['Email Type']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english',max_features=5000)
X_Vectorized = vectorizer.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_Vectorized, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 97.27%

# %%
y_predi = model.predict(X_train)
accuracy = accuracy_score(y_train, y_predi)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 99.99%

# %%
email = vectorizer.transform(["""Still havent tried Burp AI? Head to the Web Security Academy
In case you missed it, Burp Suite Professional now includes Burp AI , a set of AI-powered capabilities that help you find vulnerabilities faster by augmenting your existing workflow.

Were excited to introduce you to Burp AIs Explore issue feature, an AI-powered assistant that can autonomously investigate vulnerabilities identified by Burp Scanner, just like a human pentester. This includes:

Attempting to exploit identified vulnerabilities to validate their existence.
Identifying additional attack vectors beyond initial findings.
Generating proof-of-concept exploits to demonstrate real-world impact.
Providing step-by-step insights and an executive summary of findings for easy review.
The interactive, deliberately vulnerable labs on the Web Security Academy are designed to simulate real-world vulnerabilities in a legal, controlled environment, making them a perfect place to get hands-on with Burp AI.

Whether youre sharpening your skills or validating findings, Burp AI can help you move faster and learn more along the way. If youre a Burp Suite Professional user, or considering a trial, now is the perfect time to take the plunge as all users have access to a free bundle of 10,000 AI credits.

👉 Head to the Web Security Academy to try it today.Let us know what you think across our socials, or join the PortSwigger Discord server for access to exclusive events, feature previews, research releases, and to hang out with Burp Suite developers We’re excited to hear your feedback."""])

# %%
prediction = model.predict(email)
print("Phishing" if prediction[0] == 1 else "Legitimate")
# Out:
# Legitimate
